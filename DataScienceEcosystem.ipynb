# %% [markdown]
# <a href="https://colab.research.google.com/github/Samarjeet-singh-chhabra/bitcoin/blob/master/DataScienceEcosystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Peer-graded Assignment

# %% [markdown]
# There are a total of 25 points possible for this final project.
#
# Your grade will be based on the following Exercises:
#
# Exercise 1 - Create a Jupyter Notebook
#
# Exercise 2 - Create a markdown cell with the title of the notebook. (1 pt)
#
# Exercise 3 - Create a markdown cell for an introduction. (1 pt)
#
# Exercise 4 - Create a markdown cell to list data science languages. (3 pts)
#
# Exercise 5 - Create a markdown cell to list data science libraries. (3 pts)
#
# Exercise 6 - Create a markdown cell with a table of Data Science tools. (3 pts)
#
# Exercise 7 - Create a markdown cell introducing arithmetic expression examples. (1 pt)
#
# Exercise 8 - Create a code cell to multiply and add numbers. (2 pts)
#
# Exercise 9 - Create a code cell to convert minutes to hours. (2 pts)
#
# Exercise 10 -Insert a markdown cell to list Objectives. (3 pts)
#
# Exercise 11 - Create a markdown cell to indicate the Author’s name. (2 pts)
#
# Exercise 12 - Share your notebook through GitHub (3 pts)
#
# Exercise 13 - Take a screenshot of the first page of the notebook. (1 pt)

# %% [markdown]
# # Data Science Tools and Ecosystem   Exercise-2 and Exercise 3

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# # Exercise 4 - Create a markdown cell to list data science languages. (3 pts)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# *   Python.
# *   R.
# *   SQL.
# *   Java.
# *   Julia.
# *   Scala.
# *   C/C++.
# *   JavaScript.

# %% [markdown]
# # Exercise 5 - Create a markdown cell to list data science libraries. (3 pts)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# *   TensorFlow.
# *   NumPy.
# *   SciPy.
# *   Pandas.
# *   Matplotlib.
# *   Keras.
# *   SciKit-Learn.
# *   PyTorch.
# *   Scrapy.
# *   BeautifulSoup.
# *   LightGBM.
# *   ELI5.
# *   Theano.
# *   NuPIC.
# *   Ramp.
# *   Pipenv.
# *   Bob.
# *   PyBrain.
# *   Caffe2.
# *   Chainer.

# %% [markdown]
# # Exercise 6 - Create a markdown cell with a table of Data Science tools. (3 pts)

# %% [markdown]
# Data Science Tools:
#
#
# | Data Science Tools                   |
# |--------------------------------------|
# | SAS. It is one of those data science tools which are specifically designed for statistical operation |
# | Apache Spark                         |
# | BigML                                |

# %% [markdown]
# # Exercise 7 - Create a markdown cell introducing arithmetic expression examples. (1 pt)

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python

# %%
# Arithmetic operations
code = compile("5 + 4", "<string>", "eval")
eval(code)
# Result: 9
# Out:
# 9

# %%
code1 = compile("(5 + 7) * 2", "<string>", "eval")
eval(code1)
# Result: 24
# Out:
# 24

# %%
import math
# Volume of a sphere
code2 = compile("4 / 3 * math.pi * math.pow(25, 3)", "<string>", "eval")
eval(code2)
# Result: 65449.84694978735
# Out:
# 65449.84694978735

# %% [markdown]
# # Exercise 8 - Create a code cell to multiply and add numbers.(2 pts)

# %% [markdown]
# This a simple arithmetic expression to mutiply then add integers

# %%
(3*4)+5
# Result: 17
# Out:
# 17

# %% [markdown]
# # Exercise 9 - Create a code cell to convert minutes to hours. (2 pts)

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60

# %%
days = 0
hours = 0
mins = 0

time = 200
#days = time / 1440
leftover_minutes = time % 1440
hours = leftover_minutes / 60
#mins = time - (days*1440) - (hours*60)
print(str(days) + " days, " + str(hours) + " hours, " + str(mins) +  " mins. ")

# Result: 3.3333333333333335 hours
# Out:
# 0 days, 3.3333333333333335 hours, 0 mins.

# %% [markdown]
# # Exercise 10 -Insert a markdown cell to list Objectives.

# %% [markdown]
# Objectives:
#
# *   List popular languages that Data Scientists use.
# *   List commonly used libraries used by Data Scientists.
# *   Comment on Data Science tools.

# %% [markdown]
# # Exercise 11 - Create a markdown cell to indicate the Author’s name.

# %% [markdown]
# Author:
#
# *   Lakshmi Holla
#
# *   Niveditha Pandith

# %% [markdown]
# # Exercise 12 - Share your notebook through GitHub (3 pts)

# %% [markdown]
# [Github Link](https://github.com/Samarjeet-singh-chhabra/bitcoin/blob/master/DataScienceEcosystem.ipynb)

# %% [markdown]
# #  Exercise 13 - Take a screenshot of the first page of the notebook. (1 pt)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
